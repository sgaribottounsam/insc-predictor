# %% [markdown]
# #Getting started with pandas

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# 5.1 Introduction
# Series - one dimensional array of similar type
# * obj.array pandas wrapped array
# Dataframe

# %%
lst = [4, 7, -5, 3]
ind = ["a", "b", "c", "d"]
obj = pd.Series(data=lst, index=ind)
np.exp(obj)

dicc = {"LAGE": 29, "LECO": 12, "CP": 17}
obj2 = pd.Series(dicc)

ddata = obj.to_dict()
ddata
obj3 = pd.Series(ddata, index= ['a','b', 'f'] )
obj + obj3

# %%
populations = {"Ohio": {2000: 1.5, 2001: 1.7, 2002: 3.6},
               "Nevada": {2001: 2.4, 2002: 2.9}}
df = pd.DataFrame(populations)
#df['pop2'] = df['pop'] * 1000

df.T
# Out:
#         2000  2001  2002
# Ohio     1.5   1.7   3.6
# Nevada   NaN   2.4   2.9
