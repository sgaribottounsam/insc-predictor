# %%
#Lectura con pandas del excel que está en data
import pandas as pd
import os

ruta = os.path.join("..", "data", "crudos", "inscripciones_cursadas_2025-1.xlsx")
#print(ruta)
ruta = "/home/santiago/Proyectos/inscr-predictor/insc-predictor/data/crudos/inscripciones_cursadas_2025_1.xlsx"

df = pd.read_excel(ruta, header=5)
print(df.head())
# Out:
#                                  Alumno Identificación Legajo Comisión  \
# 0               BENITEZ, CAMILA LUCIANA   DNI 43251097    NaN     3017
# 1  DELGADO SANABRIA, ESTEFANÍA VICTORIA   DNI 46098414    NaN     3017
# 2                 FABRE, AYLEN AGUSTINA   DNI 43723455    NaN     3017
# 3                      GONZALEZ, ARIANA   DNI 43504626    NaN     3017
# 4                   LORENZO, LUNA ERICA   DNI 42194580    NaN     3017
#
#   Estado Insc.              Instancia    Fecha inscripción Exceptuado Motivo  \
# 0     Aceptada  Regularidad/Promoción  19/02/2025 15:48:36         No    NaN
# 1     Aceptada  Regularidad/Promoción  17/02/2025 23:14:43         No    NaN
# 2     Aceptada  Regularidad/Promoción  17/02/2025 13:15:30         No    NaN
# 3     Aceptada  Regularidad/Promoción  21/02/2025 15:30:49         No    NaN
# 4     Aceptada  Regularidad/Promoción  17/02/2025 14:48:45         No    NaN
#
#   Nro de Transacción Curso PV Nombre curso PV  \
# ...
